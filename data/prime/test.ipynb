# %%
import os
import pandas as pd
file_path = "/ibex/project/c2261/wenxuan/projects/verl_lora/data/prime/src/train.parquet"
df = pd.read_parquet(file_path)
print(df.iloc[0])
# Out:
# data_source                                      numina_olympiads
# prompt          [{'content': '
# When tackling complex reasoning...
# ability                                                      math
# reward_model    {'ground_truth': '\begin{pmatrix}
#    -7 & 6 & ...
# extra_info                         {'index': 0, 'split': 'dummy'}
# Name: 0, dtype: object

# %%
print(df.iloc[0]['prompt']['content'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(df.iloc[0]['prompt']['content'])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
print(df.iloc[0]['data_source'])
# Out:
# numina_olympiads

# %%
print(df.iloc[0].keys())
# Out:
# Index(['data_source', 'prompt', 'ability', 'reward_model', 'extra_info'], dtype='object')

# %%
print(df.iloc[0]["extra_info"])
# Out:
# {'index': 0, 'split': 'dummy'}

# %%
print(len(df))
# Out:
# 480537

# %%
print(df.iloc[40000]['prompt'])
# Out:
# [{'content': '\nWhen tackling complex reasoning tasks, you have access to the following actions. Use them as needed to progress through your thought process.\n\n[ASSESS]\n\n[ADVANCE]\n\n[VERIFY]\n\n[SIMPLIFY]\n\n[SYNTHESIZE]\n\n[PIVOT]\n\n[OUTPUT]\n\nYou should strictly follow the format below:\n\n[ACTION NAME]\n\n# Your action step 1\n\n# Your action step 2\n\n# Your action step 3\n\n...\n\nNext action: [NEXT ACTION NAME]\n\n', 'role': 'system'}
#  {'content': 'Given the inequality $mx^{2}+nx- \\frac{1}{m} < 0$ with the solution set $\\{x|x < - \\frac{1}{2}$ or $x > 2\\}$, find the value of $m-n$.\n\nPresent the answer in LaTex format: \\boxed{Your answer}', 'role': 'user'}]

# %%
480k
